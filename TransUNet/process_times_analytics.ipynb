# %%
import pandas as pd

# %%
df = pd.read_csv('process_times.csv')
df.head(15)
# Out:
#                                                  Step           Start Time  \
# 0                                    Video Processing  2025-04-03 14:10:25
# 1                                     Video splitting  2025-04-03 14:10:26
# 2                              NPZ file list creation  2025-04-03 14:11:09
# 3                                           Inference  2025-04-03 14:11:15
# 4                                  Insertion Plotting  2025-04-03 14:14:00
# 5               Video reconstruction Transunet coords  2025-04-03 14:15:51
# 6                    Acceleration threshold obtention  2025-04-03 14:16:00
# 7          Kalman filter for distal insertion applied  2025-04-03 14:16:00
# 8        Kalman filter for proximal insertion applied  2025-04-03 14:16:01
# 9   Finished generating image inputs corrected by ...  2025-04-03 14:16:01
# 10  Video corrected by Kalman filter reconstructio...  2025-04-03 14:16:34
#
#                End Time  Elapsed Time (seconds)
# ...

# %%
total_time = df['Elapsed Time (seconds)'].sum()
print('Total time in seconds: ', total_time)
total_time_mins = total_time/60
print('Total time in minutes: ', total_time_mins)
# Out:
# Total time in seconds:  373.47701930999756
# Total time in minutes:  6.224616988499959
